# %%
# %config IPCompleter.greedy=True

# %%
import os
import pandas as pd
dirname = "../input/"
listfile = os.listdir(dirname)
for wordname in listfile:
    if wordname == ".DS_Store":
        continue
    for csv in os.listdir(dirname + wordname):
        filepath = os.path.join(dirname, wordname, csv)
        content = pd.read_csv(filepath, sep=';')
        content.fillna(0.0)

# %%
content.describe()
# Out:
#           face_x     face_y  landmark_x_1  landmark_y_1  ...  landmark_x_41  landmark_y_41  landmark_x_42  landmark_y_42
# count  86.000000  86.000000     86.000000     86.000000  ...      27.000000      27.000000      27.000000      27.000000
# mean    0.390947   0.650027      0.615802      0.767938  ...       0.195340       0.656713       0.196746       0.630912
# std     0.030262   0.018840      0.189762      0.117175  ...       0.053336       0.095348       0.047286       0.106536
# min     0.349694   0.609130      0.159839      0.487179  ...       0.133940       0.581315       0.141083       0.553282
# 25%     0.365783   0.635456      0.639079      0.689577  ...       0.151822       0.600101       0.156712       0.562866
# 50%     0.387262   0.648494      0.701886      0.809863  ...       0.158580       0.604438       0.163602       0.567693
# 75%     0.410709   0.664505      0.717111      0.842499  ...       0.250768       0.668795       0.246868       0.650554
# max     0.506222   0.692475      0.760442      0.940903  ...       0.280754       0.908383       0.261440       0.900859
#
# [8 rows x 86 columns]

# %%
content.fillna(0.0)
# Out:
#       face_x    face_y  landmark_x_1  landmark_y_1  ...  landmark_x_41  landmark_y_41  landmark_x_42  landmark_y_42
# 0   0.357750  0.679787      0.209206      0.892009  ...       0.000000       0.000000       0.000000       0.000000
# 1   0.358928  0.677971      0.201815      0.912839  ...       0.264904       0.908383       0.236882       0.899224
# 2   0.358765  0.673758      0.217250      0.900358  ...       0.000000       0.000000       0.000000       0.000000
# 3   0.356172  0.675153      0.209563      0.902254  ...       0.277859       0.899616       0.259098       0.897143
# 4   0.359488  0.674482      0.216031      0.908862  ...       0.000000       0.000000       0.000000       0.000000
# ..       ...       ...           ...           ...  ...            ...            ...            ...            ...
# 81  0.422480  0.646773      0.312190      0.852171  ...       0.000000       0.000000       0.000000       0.000000
# 82  0.459330  0.641090      0.312152      0.834188  ...       0.000000       0.000000       0.000000       0.000000
# 83  0.468548  0.629166      0.299925      0.847060  ...       0.000000       0.000000       0.000000       0.000000
# 84  0.473777  0.620025      0.290400      0.815644  ...       0.000000       0.000000       0.000000       0.000000
# 85  0.506222  0.609130      0.279446      0.891950  ...       0.000000       0.000000       0.000000       0.000000
#
# [86 rows x 86 columns]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
text="Computer Hallo Welt Deutschland"
t = Tokenizer()
t.one_hot([text])
print
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-9072c7246734> in <module>
#       3 t = Tokenizer()
#       4 t.fit_on_texts([text])
# ----> 5 print(t.end())
#
# AttributeError: 'Tokenizer' object has no attribute 'end'
